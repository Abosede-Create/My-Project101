# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listoforders = pd.read_csv("listoforders.csv")

# %%
listoforders
# Out:
#     Order_ID  Order_Date CustomerName              State       City
# 0    B-25601  01/04/2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01/04/2018        Pearl        Maharashtra       Pune
# 2    B-25603  03/04/2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03/04/2018       Divsha          Rajasthan     Jaipur
# 4    B-25605  05/04/2018      Kasheen        West Bengal    Kolkata
# ..       ...         ...          ...                ...        ...
# 495  B-26096  28/03/2019       Atharv        West Bengal    Kolkata
# 496  B-26097  28/03/2019         Vini          Karnataka  Bangalore
# 497  B-26098  29/03/2019        Pinky  Jammu and Kashmir    Kashmir
# 498  B-26099  30/03/2019       Bhishm        Maharashtra     Mumbai
# 499  B-26100  31/03/2019       Hitika     Madhya Pradesh     Indore
#
# [500 rows x 5 columns]

# %%
listoforders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      500 non-null    object
#  1   Order_Date    500 non-null    object
#  2   CustomerName  500 non-null    object
#  3   State         500 non-null    object
#  4   City          500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
listoforders.describe()
# Out:
#        Order_ID  Order_Date CustomerName           State    City
# count       500         500          500             500     500
# unique      500         307          332              19      24
# top     B-25601  24/11/2018       Shreya  Madhya Pradesh  Indore
# freq          1           7            6             101      76

# %%
listoforders.dtypes
# Out:
# Order_ID        object
# Order_Date      object
# CustomerName    object
# State           object
# City            object
# dtype: object

# %%
listoforders.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'CustomerName', 'State', 'City'], dtype='object')

# %%
listoforders.shape
# Out:
# (500, 5)

# %%
employees_england = pd.read_csv("employees_england.csv")

# %%
employees_england
# Out:
#     Employee ID                        Name                      Email  \
# 0        EMP001                Ruth Simpson         qevans@example.net
# 1        EMP002                   Ian Heath        rosie45@example.net
# 2        EMP003         Ms Elizabeth Howard   jacqueline28@example.com
# 3        EMP004                Abdul Powell         tbooth@example.com
# 4        EMP005                   Ross Ward       huntrita@example.org
# ..          ...                         ...                        ...
# 995      EMP996                 Linda Jones         iain44@example.net
# 996      EMP997               Dr Nigel Miah   burkebradley@example.org
# 997      EMP998            Samantha Thomson      smithjake@example.org
# 998      EMP999         Miss Sian Macdonald  victorroberts@example.net
# 999     EMP1000  Georgia Edwards-O'Sullivan        bryan41@example.net
#
#                                             Job Title        Phone Number  \
# ...

# %%
employees_england.describe()
# Out:
#              Salary
# count   1000.000000
# mean   62652.446000
# std    21795.076942
# min    25027.000000
# 25%    43289.750000
# 50%    63297.000000
# 75%    81479.750000
# max    99909.000000

# %%
employees_england.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Employee ID   1000 non-null   object
#  1   Name          1000 non-null   object
#  2   Email         1000 non-null   object
#  3   Job Title     1000 non-null   object
#  4   Phone Number  1000 non-null   object
#  5   City          1000 non-null   object
#  6   Salary        1000 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
employees_england.dtypes
# Out:
# Employee ID     object
# Name            object
# Email           object
# Job Title       object
# Phone Number    object
# City            object
# Salary           int64
# dtype: object

# %%
employees_england.columns
# Out:
# Index(['Employee ID', 'Name', 'Email', 'Job Title', 'Phone Number', 'City',
#        'Salary'],
#       dtype='object')

# %%
employees_england.shape
# Out:
# (1000, 7)

# %%
order_details = pd.read_csv("order_details.csv")

# %%
order_details
# Out:
#      Order_ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601    1275   -1148         7    Furniture         Bookcases
# 1     B-25601      66     -12         5     Clothing             Stole
# 2     B-25601       8      -2         3     Clothing       Hankerchief
# 3     B-25601      80     -56         4  Electronics  Electronic Games
# 4     B-25602     168    -111         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099     835     267         5  Electronics            Phones
# 1496  B-26099    2366     552         5     Clothing          Trousers
# 1497  B-26100     828     230         2    Furniture            Chairs
# 1498  B-26100      34      10         2     Clothing           T-shirt
# 1499  B-26100      72      16         2     Clothing             Shirt
#
# [1500 rows x 6 columns]

# %%
order_details = pd.read_csv("order_details.csv")

# %%
order_details
# Out:
#      Order_ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601    1275   -1148         7    Furniture         Bookcases
# 1     B-25601      66     -12         5     Clothing             Stole
# 2     B-25601       8      -2         3     Clothing       Hankerchief
# 3     B-25601      80     -56         4  Electronics  Electronic Games
# 4     B-25602     168    -111         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099     835     267         5  Electronics            Phones
# 1496  B-26099    2366     552         5     Clothing          Trousers
# 1497  B-26100     828     230         2    Furniture            Chairs
# 1498  B-26100      34      10         2     Clothing           T-shirt
# 1499  B-26100      72      16         2     Clothing             Shirt
#
# [1500 rows x 6 columns]

# %%
order_details.plot.hist (bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
order_details["Category"].value_counts()
# Out:
# Category
# Clothing       949
# Electronics    308
# Furniture      243
# Name: count, dtype: int64

# %%
order_details.describe()
# Out:
#             Amount       Profit     Quantity
# count  1500.000000  1500.000000  1500.000000
# mean    287.668000    15.970000     3.743333
# std     461.050488   169.140565     2.184942
# min       4.000000 -1981.000000     1.000000
# 25%      45.000000    -9.250000     2.000000
# 50%     118.000000     9.000000     3.000000
# 75%     322.000000    38.000000     5.000000
# max    5729.000000  1698.000000    14.000000

# %%
order_details.columns
# Out:
# Index(['Order_ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category'], dtype='object')

# %%
order_details.shape
# Out:
# (1500, 6)

# %%
sales_target = pd.read_csv("sales_target.csv")

# %%
sales_target
# Out:
#    Month _of_Order_Date     Category   Target
# 0                Apr-18    Furniture   10,400
# 1                May-18    Furniture   10,500
# 2                Jun-18    Furniture   10,600
# 3                Jul-18    Furniture   10,800
# 4                Aug-18    Furniture   10,900
# 5                Sep-18    Furniture   11,000
# 6                Oct-18    Furniture   11,100
# 7                Nov-18    Furniture   11,300
# 8                Dec-18    Furniture   11,400
# 9                Jan-19    Furniture   11,500
# 10               Feb-19    Furniture   11,600
# 11               Mar-19    Furniture   11,800
# 12               Apr-18     Clothing   12,000
# 13               May-18     Clothing   12,000
# 14               Jun-18     Clothing   12,000
# 15               Jul-18     Clothing   14,000
# 16               Aug-18     Clothing   14,000
# 17               Sep-18     Clothing   14,000
# 18               Oct-18     Clothing   16,000
# ...

# %%
sales_target["Category"].value_counts()
# Out:
# Category
# Furniture      12
# Clothing       12
# Electronics    12
# Name: count, dtype: int64

# %%
sales_target.dtypes
# Out:
# Month _of_Order_Date    object
# Category                object
#  Target                 object
# dtype: object

# %%
sales_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month _of_Order_Date  36 non-null     object
#  1   Category              36 non-null     object
#  2    Target               36 non-null     object
# dtypes: object(3)
# memory usage: 996.0+ bytes

# %%
sales_target.columns
# Out:
# Index(['Month _of_Order_Date', 'Category', ' Target '], dtype='object')

# %%
sales_target.shape
# Out:
# (36, 3)
